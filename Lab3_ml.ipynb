# %% [markdown]
# <a href="https://colab.research.google.com/github/anishareddy04/ML_CSE_21206A/blob/main/Lab3_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #pandas are used to data manupulation
import numpy as np
from google.colab import files #importing files from google colb
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2464a6a3-81e6-42b6-a41b-8b5955d10c1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2464a6a3-81e6-42b6-a41b-8b5955d10c1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
excel = pd.ExcelFile('t5_test (1).xlsx') #aceesing the excel
data = pd.read_excel(excel, 'Sheet1')

# %%
data
# Out:
#     Unnamed: 0   embed_0   embed_1   embed_2   embed_3   embed_4   embed_5  \
# 0            0 -0.031154  0.005788  0.013190  0.032214 -0.002240 -0.007682
# 1            1 -0.008623 -0.022160  0.038645  0.047361 -0.010748  0.016291
# 2            2 -0.042335 -0.006139  0.055676  0.042178 -0.017414  0.001958
# 3            3 -0.038854 -0.012770  0.058698  0.028715 -0.006059  0.001011
# 4            4 -0.021714  0.039733  0.022342  0.029314 -0.011418  0.020631
# ..         ...       ...       ...       ...       ...       ...       ...
# 65          65  0.010180 -0.011995  0.032084  0.041886 -0.012140  0.014416
# 66          66 -0.046584 -0.038691  0.013749  0.039740 -0.041682 -0.012247
# 67          67 -0.021693 -0.049638  0.024616  0.055341 -0.032129  0.010809
# 68          68 -0.046183 -0.041136  0.026308  0.003228 -0.041647 -0.001144
# 69          69 -0.050950 -0.038060  0.031824  0.000333 -0.044964  0.007230
#
# ...
